# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignment2/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/cs231n/assignment2/cs231n/datasets
# /content/drive/My Drive/cs231n/assignment2

# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cs231n/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from Assignment 1. For right now, don't worry about implementing dropout or batch/layer normalization yet, as you will add those features later.

# %%
# Setup cell.
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# =========== You can safely ignore the message below if you are NOT working on ConvolutionalNetworks.ipynb ===========
# 	You will need to compile a Cython extension for a portion of this assignment.
# 	The instructions to do this will be given in a section of the notebook below.

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.   
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  2.3004790897684924
# W1 relative error: 7.696803870986541e-08
# W2 relative error: 1.7087519140575808e-05
# W3 relative error: 2.9508423118300657e-07
# b1 relative error: 4.660094650186831e-09
# b2 relative error: 2.085654124402131e-09
# b3 relative error: 6.598642296022133e-11
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 7.355058816898759e-09
# W2 relative error: 6.86942277940646e-08
# W3 relative error: 3.483989277228501e-08
# b1 relative error: 1.1683196894962977e-08
# b2 relative error: 1.7223751746766738e-09
# b3 relative error: 2.86824680346369e-10

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

# weight_scale = 10 ** np.random.uniform(-2, -1)   # Experiment with this!
# learning_rate = 10 ** np.random.uniform(-4, -3)   # Experiment with this!
weight_scale = 4.64e-2
learning_rate = 6.45e-4
print("weight_scale, learning_rate: %e %e" % (weight_scale, learning_rate))

model = FullyConnectedNet(
    [100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule="sgd",
    optim_config={"learning_rate": learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title("Training loss history")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# weight_scale, learning_rate: 4.640000e-02 6.450000e-04
# (Iteration 1 / 40) loss: 18.888688
# (Epoch 0 / 20) train acc: 0.220000; val_acc: 0.119000
# (Epoch 1 / 20) train acc: 0.240000; val_acc: 0.123000
# (Epoch 2 / 20) train acc: 0.460000; val_acc: 0.151000
# (Epoch 3 / 20) train acc: 0.620000; val_acc: 0.131000
# (Epoch 4 / 20) train acc: 0.740000; val_acc: 0.135000
# (Epoch 5 / 20) train acc: 0.720000; val_acc: 0.128000
# (Iteration 11 / 40) loss: 2.420989
# (Epoch 6 / 20) train acc: 0.720000; val_acc: 0.138000
# (Epoch 7 / 20) train acc: 0.800000; val_acc: 0.144000
# (Epoch 8 / 20) train acc: 0.900000; val_acc: 0.136000
# (Epoch 9 / 20) train acc: 0.960000; val_acc: 0.128000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.130000
# (Iteration 21 / 40) loss: 0.015406
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.134000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.135000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.135000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.134000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.134000
# (Iteration 31 / 40) loss: 0.001494
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.135000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.135000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.135000

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.
num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

# weight_scale = 10 ** np.random.uniform(-2, -1)   # Experiment with this!
# learning_rate = 10 ** np.random.uniform(-3, -2)   # Experiment with this!
weight_scale = 7.05e-2
learning_rate = 1.89e-3
print("weight_scale, learning_rate: %e %e" % (weight_scale, learning_rate))

model = FullyConnectedNet(
    [100, 100, 100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule='sgd',
    optim_config={'learning_rate': learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# weight_scale, learning_rate: 7.050000e-02 1.890000e-03
# (Iteration 1 / 40) loss: 29.171501
# (Epoch 0 / 20) train acc: 0.200000; val_acc: 0.099000
# (Epoch 1 / 20) train acc: 0.260000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.400000; val_acc: 0.105000
# (Epoch 3 / 20) train acc: 0.520000; val_acc: 0.116000
# (Epoch 4 / 20) train acc: 0.720000; val_acc: 0.124000
# (Epoch 5 / 20) train acc: 0.820000; val_acc: 0.102000
# (Iteration 11 / 40) loss: 0.389240
# (Epoch 6 / 20) train acc: 0.900000; val_acc: 0.106000
# (Epoch 7 / 20) train acc: 0.920000; val_acc: 0.110000
# (Epoch 8 / 20) train acc: 0.940000; val_acc: 0.113000
# (Epoch 9 / 20) train acc: 0.980000; val_acc: 0.111000
# (Epoch 10 / 20) train acc: 0.980000; val_acc: 0.117000
# (Iteration 21 / 40) loss: 0.074640
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.114000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.116000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.115000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.115000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.114000
# (Iteration 31 / 40) loss: 0.019932
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.116000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.116000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.117000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.117000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.117000

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
# [The three-layer network(?)] It is because the three-layer network has a relatively simpler structure and thus has less "bottoms" with respect to the loss, so its performance is more affected by the initialization.

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-3},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")
    
for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  sgd
# (Iteration 1 / 200) loss: 3.158404
# (Epoch 0 / 5) train acc: 0.109000; val_acc: 0.112000
# (Iteration 11 / 200) loss: 2.277982
# (Iteration 21 / 200) loss: 2.281757
# (Iteration 31 / 200) loss: 2.115932
# (Epoch 1 / 5) train acc: 0.236000; val_acc: 0.230000
# (Iteration 41 / 200) loss: 2.085815
# (Iteration 51 / 200) loss: 1.949597
# (Iteration 61 / 200) loss: 2.154302
# (Iteration 71 / 200) loss: 2.069462
# (Epoch 2 / 5) train acc: 0.289000; val_acc: 0.273000
# (Iteration 81 / 200) loss: 2.063562
# (Iteration 91 / 200) loss: 1.856070
# (Iteration 101 / 200) loss: 1.878596
# (Iteration 111 / 200) loss: 1.994481
# (Epoch 3 / 5) train acc: 0.327000; val_acc: 0.283000
# (Iteration 121 / 200) loss: 2.021148
# (Iteration 131 / 200) loss: 1.897082
# (Iteration 141 / 200) loss: 1.878311
# (Iteration 151 / 200) loss: 1.804053
# (Epoch 4 / 5) train acc: 0.361000; val_acc: 0.287000
# (Iteration 161 / 200) loss: 1.788814
# (Iteration 171 / 200) loss: 1.824918
# (Iteration 181 / 200) loss: 1.739844
# (Iteration 191 / 200) loss: 1.787161
# (Epoch 5 / 5) train acc: 0.380000; val_acc: 0.316000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 2.725999
# (Epoch 0 / 5) train acc: 0.108000; val_acc: 0.123000
# (Iteration 11 / 200) loss: 2.286593
# (Iteration 21 / 200) loss: 2.072759
# (Iteration 31 / 200) loss: 1.914781
# (Epoch 1 / 5) train acc: 0.307000; val_acc: 0.268000
# (Iteration 41 / 200) loss: 2.090296
# (Iteration 51 / 200) loss: 1.934501
# (Iteration 61 / 200) loss: 1.764468
# (Iteration 71 / 200) loss: 1.740737
# (Epoch 2 / 5) train acc: 0.380000; val_acc: 0.334000
# (Iteration 81 / 200) loss: 1.713042
# (Iteration 91 / 200) loss: 1.771047
# (Iteration 101 / 200) loss: 1.715246
# (Iteration 111 / 200) loss: 1.522302
# (Epoch 3 / 5) train acc: 0.448000; val_acc: 0.335000
# (Iteration 121 / 200) loss: 1.496484
# (Iteration 131 / 200) loss: 1.510881
# (Iteration 141 / 200) loss: 1.637230
# (Iteration 151 / 200) loss: 1.644235
# (Epoch 4 / 5) train acc: 0.486000; val_acc: 0.337000
# (Iteration 161 / 200) loss: 1.412961
# (Iteration 171 / 200) loss: 1.314958
# (Iteration 181 / 200) loss: 1.355179
# (Iteration 191 / 200) loss: 1.274423
# (Epoch 5 / 5) train acc: 0.532000; val_acc: 0.345000

# %% [markdown]
# ## RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.524687511038133e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  1.1395691798535431e-07
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )
    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': learning_rates[update_rule]},
        verbose=True
    )
    solvers[update_rule] = solver
    solver.train()
    print()
    
fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"{update_rule}")
    
for ax in axes:
    ax.legend(loc='best', ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  adam
# (Iteration 1 / 200) loss: 2.513866
# (Epoch 0 / 5) train acc: 0.122000; val_acc: 0.133000
# (Iteration 11 / 200) loss: 2.110382
# (Iteration 21 / 200) loss: 1.821537
# (Iteration 31 / 200) loss: 1.929841
# (Epoch 1 / 5) train acc: 0.372000; val_acc: 0.306000
# (Iteration 41 / 200) loss: 1.630055
# (Iteration 51 / 200) loss: 1.698057
# (Iteration 61 / 200) loss: 1.618855
# (Iteration 71 / 200) loss: 1.526940
# (Epoch 2 / 5) train acc: 0.448000; val_acc: 0.361000
# (Iteration 81 / 200) loss: 1.391678
# (Iteration 91 / 200) loss: 1.408478
# (Iteration 101 / 200) loss: 1.540306
# (Iteration 111 / 200) loss: 1.516262
# (Epoch 3 / 5) train acc: 0.519000; val_acc: 0.370000
# (Iteration 121 / 200) loss: 1.449139
# (Iteration 131 / 200) loss: 1.253267
# (Iteration 141 / 200) loss: 1.355062
# (Iteration 151 / 200) loss: 1.140239
# (Epoch 4 / 5) train acc: 0.556000; val_acc: 0.395000
# (Iteration 161 / 200) loss: 1.449049
# (Iteration 171 / 200) loss: 1.136673
# (Iteration 181 / 200) loss: 1.200157
# (Iteration 191 / 200) loss: 1.231642
# (Epoch 5 / 5) train acc: 0.566000; val_acc: 0.360000
#
# Running with  rmsprop
# (Iteration 1 / 200) loss: 2.975030
# (Epoch 0 / 5) train acc: 0.146000; val_acc: 0.133000
# (Iteration 11 / 200) loss: 2.089350
# (Iteration 21 / 200) loss: 1.913088
# (Iteration 31 / 200) loss: 1.765656
# (Epoch 1 / 5) train acc: 0.393000; val_acc: 0.309000
# (Iteration 41 / 200) loss: 1.737851
# (Iteration 51 / 200) loss: 1.643134
# (Iteration 61 / 200) loss: 1.738356
# (Iteration 71 / 200) loss: 1.705437
# (Epoch 2 / 5) train acc: 0.433000; val_acc: 0.337000
# (Iteration 81 / 200) loss: 1.551297
# (Iteration 91 / 200) loss: 1.614313
# (Iteration 101 / 200) loss: 1.720725
# (Iteration 111 / 200) loss: 1.513357
# (Epoch 3 / 5) train acc: 0.516000; val_acc: 0.367000
# (Iteration 121 / 200) loss: 1.479599
# (Iteration 131 / 200) loss: 1.484877
# (Iteration 141 / 200) loss: 1.464579
# (Iteration 151 / 200) loss: 1.552433
# (Epoch 4 / 5) train acc: 0.506000; val_acc: 0.375000
# (Iteration 161 / 200) loss: 1.287038
# (Iteration 171 / 200) loss: 1.220835
# (Iteration 181 / 200) loss: 1.560077
# (Iteration 191 / 200) loss: 1.302898
# (Epoch 5 / 5) train acc: 0.542000; val_acc: 0.391000

# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
# It is because the cache is monotonically increasing during the process of parameter updating, and therefore the learning rate would be equivalently divided by a increasingly larger number, which leads to a slower learning process. Adam doesn't have the same issue: It adopts a moving average preventing the cache from being too large.

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the assignment we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional networks rather than fully connected networks.
#
# **Note:** You might find it useful to complete the `BatchNormalization.ipynb` and `Dropout.ipynb` notebooks before completing this part, since those techniques can help you train powerful models.

# %%
best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

best_solver = None
best_val_acc = 0.0
best_train_acc = 0.0

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

for i in range(1):
    # weight_scale = 10 ** np.random.uniform(-2, -1)   # Experiment with this!
    # learning_rate = 10 ** np.random.uniform(-3.5, -2)   # Experiment with this!
    weight_scale = 5.83e-2
    learning_rate = 1.08e-3

    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=weight_scale,
        dtype=np.float64
    )
    solver = Solver(
        model,
        data,
        num_epochs=20,
        batch_size=200,
        update_rule='adam',
        optim_config={'learning_rate': learning_rate},
        verbose=True
    )
    solver.train()

    print("weight_scale, learning_rate: %e %e ---- train_acc, val_acc: %f, %f" % (weight_scale, learning_rate, solver.train_acc_history[-1], solver.best_val_acc))

    if solver.best_val_acc > best_val_acc:
        best_val_acc = solver.best_val_acc
        best_model = model
        best_solver = solver

    # if solver.train_acc_history[-1] > best_train_acc:
    #     best_train_acc = solver.train_acc_history[-1]
    #     best_model = model
    #     best_solver = solver

# print("--------------------------------------------------------------------------------------------------")
# print("best_train_acc, best_val_acc: %f %f" % (best_solver.train_acc_history[-1], best_solver.best_val_acc))

plt.plot(best_solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (Iteration 1 / 4900) loss: 4.450208
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.119000
# (Iteration 11 / 4900) loss: 2.206711
# (Iteration 21 / 4900) loss: 2.031131
# (Iteration 31 / 4900) loss: 1.981459
# (Iteration 41 / 4900) loss: 2.000427
# (Iteration 51 / 4900) loss: 1.872368
# (Iteration 61 / 4900) loss: 1.921589
# (Iteration 71 / 4900) loss: 1.761086
# (Iteration 81 / 4900) loss: 1.721779
# (Iteration 91 / 4900) loss: 1.835945
# (Iteration 101 / 4900) loss: 1.881133
# (Iteration 111 / 4900) loss: 1.631766
# (Iteration 121 / 4900) loss: 1.674168
# (Iteration 131 / 4900) loss: 1.911446
# (Iteration 141 / 4900) loss: 1.602255
# (Iteration 151 / 4900) loss: 1.610310
# (Iteration 161 / 4900) loss: 1.742037
# (Iteration 171 / 4900) loss: 1.665719
# (Iteration 181 / 4900) loss: 1.681820
# (Iteration 191 / 4900) loss: 1.600010
# (Iteration 201 / 4900) loss: 1.569093
# (Iteration 211 / 4900) loss: 1.646193
# (Iteration 221 / 4900) loss: 1.704300
# (Iteration 231 / 4900) loss: 1.677060
# (Iteration 241 / 4900) loss: 1.641032
# (Epoch 1 / 20) train acc: 0.433000; val_acc: 0.415000
# (Iteration 251 / 4900) loss: 1.616127
# (Iteration 261 / 4900) loss: 1.738522
# (Iteration 271 / 4900) loss: 1.580333
# (Iteration 281 / 4900) loss: 1.510789
# (Iteration 291 / 4900) loss: 1.697088
# (Iteration 301 / 4900) loss: 1.649816
# (Iteration 311 / 4900) loss: 1.591788
# (Iteration 321 / 4900) loss: 1.635356
# (Iteration 331 / 4900) loss: 1.618233
# (Iteration 341 / 4900) loss: 1.581369
# (Iteration 351 / 4900) loss: 1.627769
# (Iteration 361 / 4900) loss: 1.496059
# (Iteration 371 / 4900) loss: 1.648286
# (Iteration 381 / 4900) loss: 1.699132
# (Iteration 391 / 4900) loss: 1.549848
# (Iteration 401 / 4900) loss: 1.549450
# (Iteration 411 / 4900) loss: 1.632021
# (Iteration 421 / 4900) loss: 1.670413
# (Iteration 431 / 4900) loss: 1.419327
# (Iteration 441 / 4900) loss: 1.578962
# (Iteration 451 / 4900) loss: 1.478096
# (Iteration 461 / 4900) loss: 1.478847
# (Iteration 471 / 4900) loss: 1.488131
# (Iteration 481 / 4900) loss: 1.618323
# (Epoch 2 / 20) train acc: 0.477000; val_acc: 0.467000
# (Iteration 491 / 4900) loss: 1.407759
# (Iteration 501 / 4900) loss: 1.467441
# (Iteration 511 / 4900) loss: 1.529114
# (Iteration 521 / 4900) loss: 1.517615
# (Iteration 531 / 4900) loss: 1.395650
# (Iteration 541 / 4900) loss: 1.479345
# (Iteration 551 / 4900) loss: 1.321784
# (Iteration 561 / 4900) loss: 1.480300
# (Iteration 571 / 4900) loss: 1.353157
# (Iteration 581 / 4900) loss: 1.379081
# (Iteration 591 / 4900) loss: 1.407063
# (Iteration 601 / 4900) loss: 1.286195
# (Iteration 611 / 4900) loss: 1.530596
# (Iteration 621 / 4900) loss: 1.345751
# (Iteration 631 / 4900) loss: 1.359929
# (Iteration 641 / 4900) loss: 1.585725
# (Iteration 651 / 4900) loss: 1.457866
# (Iteration 661 / 4900) loss: 1.528961
# (Iteration 671 / 4900) loss: 1.508630
# (Iteration 681 / 4900) loss: 1.704835
# (Iteration 691 / 4900) loss: 1.445696
# (Iteration 701 / 4900) loss: 1.374140
# (Iteration 711 / 4900) loss: 1.289597
# (Iteration 721 / 4900) loss: 1.692618
# (Iteration 731 / 4900) loss: 1.372361
# (Epoch 3 / 20) train acc: 0.470000; val_acc: 0.487000
# (Iteration 741 / 4900) loss: 1.397710
# (Iteration 751 / 4900) loss: 1.358439
# (Iteration 761 / 4900) loss: 1.261198
# (Iteration 771 / 4900) loss: 1.306713
# (Iteration 781 / 4900) loss: 1.268489
# (Iteration 791 / 4900) loss: 1.457002
# (Iteration 801 / 4900) loss: 1.304835
# (Iteration 811 / 4900) loss: 1.482509
# (Iteration 821 / 4900) loss: 1.341593
# (Iteration 831 / 4900) loss: 1.322030
# (Iteration 841 / 4900) loss: 1.353880
# (Iteration 851 / 4900) loss: 1.408582
# (Iteration 861 / 4900) loss: 1.510802
# (Iteration 871 / 4900) loss: 1.352947
# (Iteration 881 / 4900) loss: 1.339795
# (Iteration 891 / 4900) loss: 1.375410
# (Iteration 901 / 4900) loss: 1.305136
# (Iteration 911 / 4900) loss: 1.454664
# (Iteration 921 / 4900) loss: 1.305756
# (Iteration 931 / 4900) loss: 1.353212
# (Iteration 941 / 4900) loss: 1.404160
# (Iteration 951 / 4900) loss: 1.362337
# (Iteration 961 / 4900) loss: 1.350544
# (Iteration 971 / 4900) loss: 1.370373
# (Epoch 4 / 20) train acc: 0.545000; val_acc: 0.502000
# (Iteration 981 / 4900) loss: 1.395631
# (Iteration 991 / 4900) loss: 1.359881
# (Iteration 1001 / 4900) loss: 1.248285
# (Iteration 1011 / 4900) loss: 1.405871
# (Iteration 1021 / 4900) loss: 1.303869
# (Iteration 1031 / 4900) loss: 1.335830
# (Iteration 1041 / 4900) loss: 1.212483
# (Iteration 1051 / 4900) loss: 1.411079
# (Iteration 1061 / 4900) loss: 1.417125
# (Iteration 1071 / 4900) loss: 1.189484
# (Iteration 1081 / 4900) loss: 1.322107
# (Iteration 1091 / 4900) loss: 1.420337
# (Iteration 1101 / 4900) loss: 1.459270
# (Iteration 1111 / 4900) loss: 1.280952
# (Iteration 1121 / 4900) loss: 1.212086
# (Iteration 1131 / 4900) loss: 1.305781
# (Iteration 1141 / 4900) loss: 1.343880
# (Iteration 1151 / 4900) loss: 1.415842
# (Iteration 1161 / 4900) loss: 1.394813
# (Iteration 1171 / 4900) loss: 1.332643
# (Iteration 1181 / 4900) loss: 1.324026
# (Iteration 1191 / 4900) loss: 1.292394
# (Iteration 1201 / 4900) loss: 1.338655
# (Iteration 1211 / 4900) loss: 1.340953
# (Iteration 1221 / 4900) loss: 1.274954
# (Epoch 5 / 20) train acc: 0.553000; val_acc: 0.512000
# (Iteration 1231 / 4900) loss: 1.271408
# (Iteration 1241 / 4900) loss: 1.319688
# (Iteration 1251 / 4900) loss: 1.293075
# (Iteration 1261 / 4900) loss: 1.191193
# (Iteration 1271 / 4900) loss: 1.262153
# (Iteration 1281 / 4900) loss: 1.368651
# (Iteration 1291 / 4900) loss: 1.387365
# (Iteration 1301 / 4900) loss: 1.241789
# (Iteration 1311 / 4900) loss: 1.235894
# (Iteration 1321 / 4900) loss: 1.286474
# (Iteration 1331 / 4900) loss: 1.336842
# (Iteration 1341 / 4900) loss: 1.351613
# (Iteration 1351 / 4900) loss: 1.224342
# (Iteration 1361 / 4900) loss: 1.144274
# (Iteration 1371 / 4900) loss: 1.258232
# (Iteration 1381 / 4900) loss: 1.322295
# (Iteration 1391 / 4900) loss: 1.369944
# (Iteration 1401 / 4900) loss: 1.267161
# (Iteration 1411 / 4900) loss: 1.231000
# (Iteration 1421 / 4900) loss: 1.154364
# (Iteration 1431 / 4900) loss: 1.317501
# (Iteration 1441 / 4900) loss: 1.168967
# (Iteration 1451 / 4900) loss: 1.295628
# (Iteration 1461 / 4900) loss: 1.154412
# (Epoch 6 / 20) train acc: 0.569000; val_acc: 0.492000
# (Iteration 1471 / 4900) loss: 1.299030
# (Iteration 1481 / 4900) loss: 1.241816
# (Iteration 1491 / 4900) loss: 1.371469
# (Iteration 1501 / 4900) loss: 1.198825
# (Iteration 1511 / 4900) loss: 1.235769
# (Iteration 1521 / 4900) loss: 1.275924
# (Iteration 1531 / 4900) loss: 1.300501
# (Iteration 1541 / 4900) loss: 1.198656
# (Iteration 1551 / 4900) loss: 1.267385
# (Iteration 1561 / 4900) loss: 1.167824
# (Iteration 1571 / 4900) loss: 1.117198
# (Iteration 1581 / 4900) loss: 1.281233
# (Iteration 1591 / 4900) loss: 1.175037
# (Iteration 1601 / 4900) loss: 1.027435
# (Iteration 1611 / 4900) loss: 1.256304
# (Iteration 1621 / 4900) loss: 1.227672
# (Iteration 1631 / 4900) loss: 1.266971
# (Iteration 1641 / 4900) loss: 1.164908
# (Iteration 1651 / 4900) loss: 1.136271
# (Iteration 1661 / 4900) loss: 1.213907
# (Iteration 1671 / 4900) loss: 1.318773
# (Iteration 1681 / 4900) loss: 1.275847
# (Iteration 1691 / 4900) loss: 1.337342
# (Iteration 1701 / 4900) loss: 1.213538
# (Iteration 1711 / 4900) loss: 1.374249
# (Epoch 7 / 20) train acc: 0.571000; val_acc: 0.496000
# (Iteration 1721 / 4900) loss: 1.142959
# (Iteration 1731 / 4900) loss: 1.285451
# (Iteration 1741 / 4900) loss: 1.182479
# (Iteration 1751 / 4900) loss: 1.072063
# (Iteration 1761 / 4900) loss: 1.258790
# (Iteration 1771 / 4900) loss: 1.186524
# (Iteration 1781 / 4900) loss: 1.360221
# (Iteration 1791 / 4900) loss: 1.201869
# (Iteration 1801 / 4900) loss: 1.225076
# (Iteration 1811 / 4900) loss: 1.029254
# (Iteration 1821 / 4900) loss: 1.231586
# (Iteration 1831 / 4900) loss: 1.161416
# (Iteration 1841 / 4900) loss: 1.156493
# (Iteration 1851 / 4900) loss: 1.217469
# (Iteration 1861 / 4900) loss: 1.163579
# (Iteration 1871 / 4900) loss: 1.139612
# (Iteration 1881 / 4900) loss: 1.200502
# (Iteration 1891 / 4900) loss: 1.170142
# (Iteration 1901 / 4900) loss: 1.221862
# (Iteration 1911 / 4900) loss: 1.135020
# (Iteration 1921 / 4900) loss: 1.303177
# (Iteration 1931 / 4900) loss: 1.133564
# (Iteration 1941 / 4900) loss: 1.150481
# (Iteration 1951 / 4900) loss: 1.214155
# (Epoch 8 / 20) train acc: 0.601000; val_acc: 0.504000
# (Iteration 1961 / 4900) loss: 1.064305
# (Iteration 1971 / 4900) loss: 1.054165
# (Iteration 1981 / 4900) loss: 1.195911
# (Iteration 1991 / 4900) loss: 1.136189
# (Iteration 2001 / 4900) loss: 1.201500
# (Iteration 2011 / 4900) loss: 1.288120
# (Iteration 2021 / 4900) loss: 1.227077
# (Iteration 2031 / 4900) loss: 1.256346
# (Iteration 2041 / 4900) loss: 1.111819
# (Iteration 2051 / 4900) loss: 1.111219
# (Iteration 2061 / 4900) loss: 1.064469
# (Iteration 2071 / 4900) loss: 1.090763
# (Iteration 2081 / 4900) loss: 1.144801
# (Iteration 2091 / 4900) loss: 1.166477
# (Iteration 2101 / 4900) loss: 1.168098
# (Iteration 2111 / 4900) loss: 1.021363
# (Iteration 2121 / 4900) loss: 1.174729
# (Iteration 2131 / 4900) loss: 1.215525
# (Iteration 2141 / 4900) loss: 1.134573
# (Iteration 2151 / 4900) loss: 1.063771
# (Iteration 2161 / 4900) loss: 1.077294
# (Iteration 2171 / 4900) loss: 1.083085
# (Iteration 2181 / 4900) loss: 1.110421
# (Iteration 2191 / 4900) loss: 1.293016
# (Iteration 2201 / 4900) loss: 1.162958
# (Epoch 9 / 20) train acc: 0.599000; val_acc: 0.527000
# (Iteration 2211 / 4900) loss: 1.155825
# (Iteration 2221 / 4900) loss: 1.039226
# (Iteration 2231 / 4900) loss: 1.053082
# (Iteration 2241 / 4900) loss: 1.102583
# (Iteration 2251 / 4900) loss: 1.087388
# (Iteration 2261 / 4900) loss: 1.214945
# (Iteration 2271 / 4900) loss: 1.126741
# (Iteration 2281 / 4900) loss: 1.254871
# (Iteration 2291 / 4900) loss: 1.048893
# (Iteration 2301 / 4900) loss: 1.138468
# (Iteration 2311 / 4900) loss: 1.262654
# (Iteration 2321 / 4900) loss: 1.113792
# (Iteration 2331 / 4900) loss: 1.108939
# (Iteration 2341 / 4900) loss: 1.200502
# (Iteration 2351 / 4900) loss: 1.091260
# (Iteration 2361 / 4900) loss: 1.301330
# (Iteration 2371 / 4900) loss: 1.180386
# (Iteration 2381 / 4900) loss: 1.234660
# (Iteration 2391 / 4900) loss: 1.204719
# (Iteration 2401 / 4900) loss: 1.079967
# (Iteration 2411 / 4900) loss: 1.125979
# (Iteration 2421 / 4900) loss: 1.106283
# (Iteration 2431 / 4900) loss: 1.049693
# (Iteration 2441 / 4900) loss: 1.050747
# (Epoch 10 / 20) train acc: 0.625000; val_acc: 0.511000
# (Iteration 2451 / 4900) loss: 1.232493
# (Iteration 2461 / 4900) loss: 1.074296
# (Iteration 2471 / 4900) loss: 1.096299
# (Iteration 2481 / 4900) loss: 1.078329
# (Iteration 2491 / 4900) loss: 1.085847
# (Iteration 2501 / 4900) loss: 1.122533
# (Iteration 2511 / 4900) loss: 1.142098
# (Iteration 2521 / 4900) loss: 1.066076
# (Iteration 2531 / 4900) loss: 1.067786
# (Iteration 2541 / 4900) loss: 1.125332
# (Iteration 2551 / 4900) loss: 1.023939
# (Iteration 2561 / 4900) loss: 1.086487
# (Iteration 2571 / 4900) loss: 0.965692
# (Iteration 2581 / 4900) loss: 1.095480
# (Iteration 2591 / 4900) loss: 1.068399
# (Iteration 2601 / 4900) loss: 1.001113
# (Iteration 2611 / 4900) loss: 0.982217
# (Iteration 2621 / 4900) loss: 1.012750
# (Iteration 2631 / 4900) loss: 1.150741
# (Iteration 2641 / 4900) loss: 1.099069
# (Iteration 2651 / 4900) loss: 1.129975
# (Iteration 2661 / 4900) loss: 0.953878
# (Iteration 2671 / 4900) loss: 1.191702
# (Iteration 2681 / 4900) loss: 1.315173
# (Iteration 2691 / 4900) loss: 1.019774
# (Epoch 11 / 20) train acc: 0.618000; val_acc: 0.511000
# (Iteration 2701 / 4900) loss: 1.105104
# (Iteration 2711 / 4900) loss: 0.962466
# (Iteration 2721 / 4900) loss: 0.971568
# (Iteration 2731 / 4900) loss: 1.125935
# (Iteration 2741 / 4900) loss: 0.817597
# (Iteration 2751 / 4900) loss: 1.257428
# (Iteration 2761 / 4900) loss: 1.208291
# (Iteration 2771 / 4900) loss: 1.038328
# (Iteration 2781 / 4900) loss: 1.061696
# (Iteration 2791 / 4900) loss: 1.026440
# (Iteration 2801 / 4900) loss: 0.978133
# (Iteration 2811 / 4900) loss: 0.989057
# (Iteration 2821 / 4900) loss: 0.987462
# (Iteration 2831 / 4900) loss: 1.170053
# (Iteration 2841 / 4900) loss: 1.026098
# (Iteration 2851 / 4900) loss: 1.097780
# (Iteration 2861 / 4900) loss: 1.181012
# (Iteration 2871 / 4900) loss: 0.986180
# (Iteration 2881 / 4900) loss: 1.109836
# (Iteration 2891 / 4900) loss: 1.245864
# (Iteration 2901 / 4900) loss: 1.050214
# (Iteration 2911 / 4900) loss: 1.099504
# (Iteration 2921 / 4900) loss: 1.009534
# (Iteration 2931 / 4900) loss: 1.032692
# (Epoch 12 / 20) train acc: 0.617000; val_acc: 0.520000
# (Iteration 2941 / 4900) loss: 1.049527
# (Iteration 2951 / 4900) loss: 0.957592
# (Iteration 2961 / 4900) loss: 1.040140
# (Iteration 2971 / 4900) loss: 1.102355
# (Iteration 2981 / 4900) loss: 1.051656
# (Iteration 2991 / 4900) loss: 1.033691
# (Iteration 3001 / 4900) loss: 1.055134
# (Iteration 3011 / 4900) loss: 1.126798
# (Iteration 3021 / 4900) loss: 0.983442
# (Iteration 3031 / 4900) loss: 0.966437
# (Iteration 3041 / 4900) loss: 1.006670
# (Iteration 3051 / 4900) loss: 1.090479
# (Iteration 3061 / 4900) loss: 0.895574
# (Iteration 3071 / 4900) loss: 1.010884
# (Iteration 3081 / 4900) loss: 0.908590
# (Iteration 3091 / 4900) loss: 0.944227
# (Iteration 3101 / 4900) loss: 1.106486
# (Iteration 3111 / 4900) loss: 1.096059
# (Iteration 3121 / 4900) loss: 0.897179
# (Iteration 3131 / 4900) loss: 0.946495
# (Iteration 3141 / 4900) loss: 1.020465
# (Iteration 3151 / 4900) loss: 1.036005
# (Iteration 3161 / 4900) loss: 0.977639
# (Iteration 3171 / 4900) loss: 1.021888
# (Iteration 3181 / 4900) loss: 0.995891
# (Epoch 13 / 20) train acc: 0.645000; val_acc: 0.506000
# (Iteration 3191 / 4900) loss: 0.910573
# (Iteration 3201 / 4900) loss: 1.112087
# (Iteration 3211 / 4900) loss: 1.015591
# (Iteration 3221 / 4900) loss: 1.108491
# (Iteration 3231 / 4900) loss: 0.997496
# (Iteration 3241 / 4900) loss: 1.174933
# (Iteration 3251 / 4900) loss: 1.045134
# (Iteration 3261 / 4900) loss: 1.075173
# (Iteration 3271 / 4900) loss: 0.982297
# (Iteration 3281 / 4900) loss: 1.096525
# (Iteration 3291 / 4900) loss: 1.071476
# (Iteration 3301 / 4900) loss: 1.051380
# (Iteration 3311 / 4900) loss: 0.893925
# (Iteration 3321 / 4900) loss: 0.833293
# (Iteration 3331 / 4900) loss: 0.985902
# (Iteration 3341 / 4900) loss: 1.105593
# (Iteration 3351 / 4900) loss: 1.060033
# (Iteration 3361 / 4900) loss: 0.958124
# (Iteration 3371 / 4900) loss: 1.015763
# (Iteration 3381 / 4900) loss: 1.029203
# (Iteration 3391 / 4900) loss: 0.941448
# (Iteration 3401 / 4900) loss: 1.066302
# (Iteration 3411 / 4900) loss: 0.965817
# (Iteration 3421 / 4900) loss: 1.081229
# (Epoch 14 / 20) train acc: 0.691000; val_acc: 0.520000
# (Iteration 3431 / 4900) loss: 1.059159
# (Iteration 3441 / 4900) loss: 0.986771
# (Iteration 3451 / 4900) loss: 1.010925
# (Iteration 3461 / 4900) loss: 1.057927
# (Iteration 3471 / 4900) loss: 1.032475
# (Iteration 3481 / 4900) loss: 0.875319
# (Iteration 3491 / 4900) loss: 1.011619
# (Iteration 3501 / 4900) loss: 1.013276
# (Iteration 3511 / 4900) loss: 1.132997
# (Iteration 3521 / 4900) loss: 1.129778
# (Iteration 3531 / 4900) loss: 1.029203
# (Iteration 3541 / 4900) loss: 1.001982
# (Iteration 3551 / 4900) loss: 1.004716
# (Iteration 3561 / 4900) loss: 1.000579
# (Iteration 3571 / 4900) loss: 1.021943
# (Iteration 3581 / 4900) loss: 1.123742
# (Iteration 3591 / 4900) loss: 1.062019
# (Iteration 3601 / 4900) loss: 0.998035
# (Iteration 3611 / 4900) loss: 1.096881
# (Iteration 3621 / 4900) loss: 0.940074
# (Iteration 3631 / 4900) loss: 1.001458
# (Iteration 3641 / 4900) loss: 0.785256
# (Iteration 3651 / 4900) loss: 0.861503
# (Iteration 3661 / 4900) loss: 0.922122
# (Iteration 3671 / 4900) loss: 1.106615
# (Epoch 15 / 20) train acc: 0.650000; val_acc: 0.514000
# (Iteration 3681 / 4900) loss: 1.026841
# (Iteration 3691 / 4900) loss: 0.973499
# (Iteration 3701 / 4900) loss: 1.032811
# (Iteration 3711 / 4900) loss: 0.912160
# (Iteration 3721 / 4900) loss: 0.871557
# (Iteration 3731 / 4900) loss: 1.078589
# (Iteration 3741 / 4900) loss: 0.969373
# (Iteration 3751 / 4900) loss: 0.859587
# (Iteration 3761 / 4900) loss: 0.900882
# (Iteration 3771 / 4900) loss: 1.027655
# (Iteration 3781 / 4900) loss: 0.961260
# (Iteration 3791 / 4900) loss: 1.011222
# (Iteration 3801 / 4900) loss: 0.986805
# (Iteration 3811 / 4900) loss: 0.999126
# (Iteration 3821 / 4900) loss: 0.998563
# (Iteration 3831 / 4900) loss: 0.930882
# (Iteration 3841 / 4900) loss: 1.008304
# (Iteration 3851 / 4900) loss: 0.922387
# (Iteration 3861 / 4900) loss: 0.871916
# (Iteration 3871 / 4900) loss: 0.917465
# (Iteration 3881 / 4900) loss: 0.904408
# (Iteration 3891 / 4900) loss: 1.016800
# (Iteration 3901 / 4900) loss: 0.946699
# (Iteration 3911 / 4900) loss: 0.984304
# (Epoch 16 / 20) train acc: 0.684000; val_acc: 0.525000
# (Iteration 3921 / 4900) loss: 0.978382
# (Iteration 3931 / 4900) loss: 0.961766
# (Iteration 3941 / 4900) loss: 0.997722
# (Iteration 3951 / 4900) loss: 0.971825
# (Iteration 3961 / 4900) loss: 1.052762
# (Iteration 3971 / 4900) loss: 1.002460
# (Iteration 3981 / 4900) loss: 0.805285
# (Iteration 3991 / 4900) loss: 1.089413
# (Iteration 4001 / 4900) loss: 0.904053
# (Iteration 4011 / 4900) loss: 0.965241
# (Iteration 4021 / 4900) loss: 1.101893
# (Iteration 4031 / 4900) loss: 1.050968
# (Iteration 4041 / 4900) loss: 1.049463
# (Iteration 4051 / 4900) loss: 0.845050
# (Iteration 4061 / 4900) loss: 0.842671
# (Iteration 4071 / 4900) loss: 0.949385
# (Iteration 4081 / 4900) loss: 0.907859
# (Iteration 4091 / 4900) loss: 0.993407
# (Iteration 4101 / 4900) loss: 0.822179
# (Iteration 4111 / 4900) loss: 0.976990
# (Iteration 4121 / 4900) loss: 0.856476
# (Iteration 4131 / 4900) loss: 0.965448
# (Iteration 4141 / 4900) loss: 0.990933
# (Iteration 4151 / 4900) loss: 0.958838
# (Iteration 4161 / 4900) loss: 1.010014
# (Epoch 17 / 20) train acc: 0.710000; val_acc: 0.507000
# (Iteration 4171 / 4900) loss: 0.824448
# (Iteration 4181 / 4900) loss: 0.910632
# (Iteration 4191 / 4900) loss: 0.969409
# (Iteration 4201 / 4900) loss: 0.815767
# (Iteration 4211 / 4900) loss: 0.901183
# (Iteration 4221 / 4900) loss: 0.727922
# (Iteration 4231 / 4900) loss: 0.859325
# (Iteration 4241 / 4900) loss: 1.015742
# (Iteration 4251 / 4900) loss: 0.890847
# (Iteration 4261 / 4900) loss: 0.948327
# (Iteration 4271 / 4900) loss: 0.932390
# (Iteration 4281 / 4900) loss: 0.905945
# (Iteration 4291 / 4900) loss: 0.933336
# (Iteration 4301 / 4900) loss: 0.895208
# (Iteration 4311 / 4900) loss: 0.925821
# (Iteration 4321 / 4900) loss: 0.827110
# (Iteration 4331 / 4900) loss: 0.914592
# (Iteration 4341 / 4900) loss: 0.925681
# (Iteration 4351 / 4900) loss: 0.971500
# (Iteration 4361 / 4900) loss: 1.003793
# (Iteration 4371 / 4900) loss: 0.955898
# (Iteration 4381 / 4900) loss: 0.897098
# (Iteration 4391 / 4900) loss: 1.028542
# (Iteration 4401 / 4900) loss: 0.941804
# (Epoch 18 / 20) train acc: 0.685000; val_acc: 0.514000
# (Iteration 4411 / 4900) loss: 0.789839
# (Iteration 4421 / 4900) loss: 0.892860
# (Iteration 4431 / 4900) loss: 0.880951
# (Iteration 4441 / 4900) loss: 0.897956
# (Iteration 4451 / 4900) loss: 0.969734
# (Iteration 4461 / 4900) loss: 0.881870
# (Iteration 4471 / 4900) loss: 0.907344
# (Iteration 4481 / 4900) loss: 0.941591
# (Iteration 4491 / 4900) loss: 0.904056
# (Iteration 4501 / 4900) loss: 0.861910
# (Iteration 4511 / 4900) loss: 0.948013
# (Iteration 4521 / 4900) loss: 0.789079
# (Iteration 4531 / 4900) loss: 0.927665
# (Iteration 4541 / 4900) loss: 0.943167
# (Iteration 4551 / 4900) loss: 0.933514
# (Iteration 4561 / 4900) loss: 0.921970
# (Iteration 4571 / 4900) loss: 0.982677
# (Iteration 4581 / 4900) loss: 0.956228
# (Iteration 4591 / 4900) loss: 0.835838
# (Iteration 4601 / 4900) loss: 0.834449
# (Iteration 4611 / 4900) loss: 0.924598
# (Iteration 4621 / 4900) loss: 0.872165
# (Iteration 4631 / 4900) loss: 0.832096
# (Iteration 4641 / 4900) loss: 0.828743
# (Iteration 4651 / 4900) loss: 1.022087
# (Epoch 19 / 20) train acc: 0.660000; val_acc: 0.513000
# (Iteration 4661 / 4900) loss: 0.832160
# (Iteration 4671 / 4900) loss: 0.907370
# (Iteration 4681 / 4900) loss: 0.985442
# (Iteration 4691 / 4900) loss: 0.813637
# (Iteration 4701 / 4900) loss: 0.906283
# (Iteration 4711 / 4900) loss: 0.938867
# (Iteration 4721 / 4900) loss: 0.858985
# (Iteration 4731 / 4900) loss: 0.947778
# (Iteration 4741 / 4900) loss: 0.861144
# (Iteration 4751 / 4900) loss: 0.911367
# (Iteration 4761 / 4900) loss: 0.890613
# (Iteration 4771 / 4900) loss: 0.907414
# (Iteration 4781 / 4900) loss: 0.820453
# (Iteration 4791 / 4900) loss: 0.769791
# (Iteration 4801 / 4900) loss: 0.874652
# (Iteration 4811 / 4900) loss: 0.743559
# (Iteration 4821 / 4900) loss: 0.812907
# (Iteration 4831 / 4900) loss: 0.824826
# (Iteration 4841 / 4900) loss: 0.719992
# (Iteration 4851 / 4900) loss: 0.915686
# (Iteration 4861 / 4900) loss: 0.888958
# (Iteration 4871 / 4900) loss: 0.748385
# (Iteration 4881 / 4900) loss: 0.798932
# (Iteration 4891 / 4900) loss: 0.858275
# (Epoch 20 / 20) train acc: 0.716000; val_acc: 0.507000
# weight_scale, learning_rate: 5.830000e-02 1.080000e-03 ---- train_acc, val_acc: 0.716000, 0.527000

# %% [markdown]
# # Test Your Model!
# Run your best model on the validation and test sets. You should achieve at least 50% accuracy on the validation set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.527
# Test set accuracy:  0.497
